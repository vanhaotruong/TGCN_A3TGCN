# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset, Dataset
import random, math
from torch.utils.data import random_split
from pytorch_lightning import Trainer

from collections import defaultdict
import warnings
warnings.filterwarnings('ignore')

import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
seed = 42

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
import torch
import torch.nn.functional as F
from torch_geometric_temporal.nn.recurrent import TGCN

class TGCNRecommender(torch.nn.Module):
    def __init__(self, node_features, hidden_dim):
        super(TGCNRecommender, self).__init__()
        # Initialize TGCN layer
        self.tgcn = TGCN(node_features, hidden_dim)
        # Final prediction layer (e.g., to predict a value for each node)
        self.linear = torch.nn.Linear(hidden_dim, 1)

    def forward(self, x, edge_index, edge_weight, h):
        """
        x: (nodes, features)
        h: (nodes, hidden_dim) - previous hidden state
        """
        # TGCN returns the NEW hidden state
        h_new = self.tgcn(x, edge_index, edge_weight, h)
        
        # Pass the hidden state through a linear layer for final output
        out = self.linear(h_new)
        
        return out, h_new

# Example Usage
num_nodes = 100
node_features = 8
hidden_dim = 32

model = TGCNRecommender(node_features, hidden_dim)

# Mock data for 2 time steps
x_t0 = torch.randn(num_nodes, node_features)
x_t1 = torch.randn(num_nodes, node_features)
edge_index = torch.randint(0, num_nodes, (2, 200))

# Step 0: Initial hidden state is None (will be zeros internally)
out0, h0 = model(x_t0, edge_index, None, None)

# Step 1: Pass the hidden state from t0 to t1
out1, h1 = model(x_t1, edge_index, None, h0)

print(f"Output shape: {out1.shape}") # Expect (num_nodes, 1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import torch
#       2 import torch.nn.functional as F
# ----> 3 from torch_geometric_temporal.nn.recurrent import TGCN
#       5 class TGCNRecommender(torch.nn.Module):
#       6     def __init__(self, node_features, hidden_dim):
#
# File ~/miniconda3/envs/rs_env/lib/python3.11/site-packages/torch_geometric_temporal/__init__.py:1
# ----> 1 from torch_geometric_temporal.nn import *
#       2 from torch_geometric_temporal.dataset import *
#       3 from torch_geometric_temporal.signal import *
#
# File ~/miniconda3/envs/rs_env/lib/python3.11/site-packages/torch_geometric_temporal/nn/__init__.py:1
# ----> 1 from .recurrent import *
#       2 from .attention import *
#       3 from .hetero import *
#
# File ~/miniconda3/envs/rs_env/lib/python3.11/site-packages/torch_geometric_temporal/nn/recurrent/__init__.py:1
# ----> 1 from .gconv_gru import GConvGRU
#       2 from .gconv_lstm import GConvLSTM
#       3 from .lrgcn import LRGCN
#
# File ~/miniconda3/envs/rs_env/lib/python3.11/site-packages/torch_geometric_temporal/nn/recurrent/gconv_gru.py:2
#       1 import torch
# ----> 2 from torch_geometric.nn import ChebConv
#       5 class GConvGRU(torch.nn.Module):
#       6     r"""An implementation of the Chebyshev Graph Convolutional Gated Recurrent Unit
#       7     Cell. For details see this paper: `"Structured Sequence Modeling with Graph
#       8     Convolutional Recurrent Networks." <https://arxiv.org/abs/1612.07659>`_
#    (...)     35             an additive bias. (default: :obj:`True`)
#      36     """
#
# File ~/miniconda3/envs/rs_env/lib/python3.11/site-packages/torch_geometric/__init__.py:22
#      20 import torch_geometric.loader
#      21 import torch_geometric.transforms
# ---> 22 import torch_geometric.datasets
#      23 import torch_geometric.nn
#      24 import torch_geometric.explain
#
# File ~/miniconda3/envs/rs_env/lib/python3.11/site-packages/torch_geometric/datasets/__init__.py:82
#      80 from .web_qsp_dataset import WebQSPDataset, CWQDataset
#      81 from .git_mol_dataset import GitMolDataset
# ---> 82 from .molecule_gpt_dataset import MoleculeGPTDataset
#      83 from .instruct_mol_dataset import InstructMolDataset
#      84 from .protein_mpnn_dataset import ProteinMPNNDataset
#
# File ~/miniconda3/envs/rs_env/lib/python3.11/site-packages/torch_geometric/datasets/molecule_gpt_dataset.py:11
#       8 from typing import Callable, List, Optional, Tuple
#      10 import numpy as np
# ---> 11 import requests
#      12 import torch
#      13 from tqdm import tqdm
#
# File ~/miniconda3/envs/rs_env/lib/python3.11/site-packages/requests/__init__.py:43
#       6 """
#       7 Requests HTTP Library
#       8 ~~~~~~~~~~~~~~~~~~~~~
#    (...)     38 :license: Apache 2.0, see LICENSE for more details.
#      39 """
#      41 import warnings
# ---> 43 import urllib3
#      45 from .exceptions import RequestsDependencyWarning
#      47 try:
#
# ModuleNotFoundError: No module named 'urllib3'
